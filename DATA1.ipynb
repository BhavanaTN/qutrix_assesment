# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

myFile=pd.read_csv('C:\\Users\\BHAVANA TN\\Desktop\\campus project\qutrix_chart_work.csv',delimiter=',')
sums=myFile.groupby(myFile["Product Name;"])["Number Of Bugs"].sum()


plt.plot(sums,sums.index)
plt.xlabel("no.of bugs")
plt.ylabel("product name")
# Out:
# Text(0, 0.5, 'product name')

# %%
plt.pie(sums,labels=sums.index,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21c292a1b08>,
# ...
#  [Text(0.7874874388907211, 0.7680257375826235, 'Arista Router;'),
#   Text(-0.6240965629284709, 0.9058164715552866, 'Cisco Router;'),
#   Text(-1.0610534956090945, 0.2901128736470024, 'Cisco Switch'),
#   Text(-1.076802746498965, -0.22471280589295836, 'Dell Server;'),
#   Text(-0.11903574944140569, -1.0935403469259481, 'HP Server;'),
#   Text(1.0081893827844766, -0.439947915599854, 'Juniper Router;')],
#  [Text(0.42953860303130237, 0.41892312959052186, '24.60%'),
#   Text(-0.34041630705189324, 0.494081711757429, '20.00%'),
#   Text(-0.578756452150415, 0.15824338562563767, '2.30%'),
#   Text(-0.587346952635799, -0.1225706213961591, '12.74%'),
#   Text(-0.06492859060440309, -0.5964765528686989, '27.26%'),
#   Text(0.5499214815188054, -0.23997159032719306, '13.10%')])
